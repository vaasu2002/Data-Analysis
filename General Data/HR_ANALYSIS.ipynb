# %% [markdown]
# # HR ANALYTICS
#
# **Problem Statement-**
# A large company named XYZ, employs, at any given point of time, around 4000 employees. However, every year, around 15% of its employees leave the company and need to be replaced with the talent pool available in the job market. The management believes that this level of attrition (employees leaving, either on their own or because they got fired) is bad for the company, because of the following reasons - The former employees’ projects get delayed, which makes it difficult to meet timelines, resulting in a reputation loss among consumers and partners A sizeable department has to be maintained, for the purposes of recruiting new talent More often than not, the new employees have to be trained for the job and/or given time to acclimatise themselves to the company Hence, the management has contracted an HR analytics firm to understand what factors they should focus on, in order to curb attrition. In other words, they want to know what changes they should make to their workplace, in order to get most of their employees to stay. Also, they want to know which of these variables is most important and needs to be addressed right away.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('https://raw.githubusercontent.com/vaasu2002/Data-Analysis/main/General%20Data/general_data.csv')
df.head()
# Out:
#    Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0   51        No  ...                       0                    0
# 1   31       Yes  ...                       1                    4
# 2   32        No  ...                       0                    3
# 3   38        No  ...                       7                    5
# 4   32        No  ...                       0                    4
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (4410, 24)

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# ## OUTLIER

# %%
plt.figure(figsize=(16,7))
plt.subplot(1,12,1)
sns.boxplot(y='Age', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,2)
sns.boxplot(y='DistanceFromHome', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,3)
sns.boxplot(y='MonthlyIncome', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,4)
sns.boxplot(y='NumCompaniesWorked', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,5)
sns.boxplot(y='PercentSalaryHike', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,6)
sns.boxplot(y='StandardHours', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,7)
sns.boxplot(y='StockOptionLevel', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,8)
sns.boxplot(y='TotalWorkingYears', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,9)
sns.boxplot(y='TrainingTimesLastYear', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,10)
sns.boxplot(y='YearsAtCompany', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,11)
sns.boxplot(y='YearsSinceLastPromotion', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,12)
sns.boxplot(y='YearsWithCurrManager', data=df)
plt.xticks(rotation=45)
# Out:
# (array([0]), <a list of 1 Text major ticklabel objects>)

# %%
def outlier_remove(name):
  upper_limit = df[name].mean() + 3*df[name].std()
  lower_limit = df[name].mean() -3*df[name].std()
  df[name] = df[( df[name]<upper_limit) & ( df[name]>lower_limit)]

a = ['Age','DistanceFromHome', 'MonthlyIncome',
       'NumCompaniesWorked', 'PercentSalaryHike',
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
for i in a:
  outlier_remove(i)

# %%
plt.figure(figsize=(16,7))
plt.subplot(1,12,1)
sns.boxplot(y='Age', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,2)
sns.boxplot(y='DistanceFromHome', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,3)
sns.boxplot(y='MonthlyIncome', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,4)
sns.boxplot(y='NumCompaniesWorked', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,5)
sns.boxplot(y='PercentSalaryHike', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,6)
sns.boxplot(y='StandardHours', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,7)
sns.boxplot(y='StockOptionLevel', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,8)
sns.boxplot(y='TotalWorkingYears', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,9)
sns.boxplot(y='TrainingTimesLastYear', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,10)
sns.boxplot(y='YearsAtCompany', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,11)
sns.boxplot(y='YearsSinceLastPromotion', data=df)
plt.xticks(rotation=45)

plt.figure(figsize=(16,7))
plt.subplot(1,12,12)
sns.boxplot(y='YearsWithCurrManager', data=df)
plt.xticks(rotation=45)
# Out:
# (array([0]), <a list of 1 Text major ticklabel objects>)

# %%
df.shape
# Out:
# (4410, 24)

# %%
df.isnull().sum()
# Out:
# Age                          0
# Attrition                    0
# BusinessTravel               0
# Department                   0
# DistanceFromHome             0
# Education                    0
# EducationField               0
# EmployeeCount                0
# EmployeeID                   0
# Gender                       0
# JobLevel                     0
# JobRole                      0
# MaritalStatus                0
# MonthlyIncome                0
# NumCompaniesWorked          19
# Over18                       0
# PercentSalaryHike            0
# StandardHours                0
# StockOptionLevel             0
# TotalWorkingYears           57
# TrainingTimesLastYear        0
# YearsAtCompany              75
# YearsSinceLastPromotion    126
# YearsWithCurrManager        42
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.shape
# Out:
# (4160, 24)

# %% [markdown]
# Total data reduced from 4410 to 4160.

# %%
df.head()
# Out:
#   Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0  51        No  ...                      51                   51
# 1  31       Yes  ...                      31                   31
# 2  32        No  ...                      32                   32
# 3  38        No  ...                      38                   38
# 4  32        No  ...                      32                   32
#
# [5 rows x 24 columns]

# %%
df['Department'].value_counts()
# Out:
# Research & Development    2718
# Sales                     1261
# Human Resources            181
# Name: Department, dtype: int64

# %%
df['Education'].value_counts()
# Out:
# 3    1620
# 4    1113
# 2     815
# 1     475
# 5     137
# Name: Education, dtype: int64

# %%
df['EducationField'].value_counts()
# Out:
# Life Sciences       1722
# Medical             1322
# Marketing            448
# Technical Degree     359
# Other                229
# Human Resources       80
# Name: EducationField, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      2503
# Female    1657
# Name: Gender, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# Sales Executive              912
# Research Scientist           830
# Laboratory Technician        728
# Manufacturing Director       405
# Healthcare Representative    386
# Manager                      275
# Sales Representative         237
# Research Director            234
# Human Resources              153
# Name: JobRole, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married     1908
# Single      1339
# Divorced     913
# Name: MaritalStatus, dtype: int64

# %%
df['Over18'].value_counts()
# Out:
# Y    4160
# Name: Over18, dtype: int64

# %% [markdown]
# **Everyone is above age of 18 years**

# %%
sns.set_style('whitegrid')
sns.countplot(x='Gender',data=df)

# %%
df['JobRole'].hist(color='red',bins=40,figsize=(20,10))

# %%
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(25,11)})
sns.countplot(x='JobRole',hue='Gender',data=df,palette='rainbow')

# %%
df['EducationField'].hist(color='blue',bins=10,figsize=(10,10))

# %%
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(25,11)})
sns.countplot(x='EducationField',hue='Gender',data=df,palette='rainbow')

# %%
sns.countplot(x='Age',data=df)

# %%
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(25,11)})
sns.countplot(x='Age',hue='Gender',data=df,palette='rainbow')

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['MaritalStatus'],order=df['MaritalStatus'].value_counts().index, palette='viridis')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(25,11)})
sns.countplot(x='MaritalStatus',hue='Gender',data=df,palette='rainbow')

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['Attrition'],order=df['Attrition'].value_counts().index)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(25,11)})
sns.countplot(x='Gender',hue='Attrition',data=df,palette='rainbow')

# %%
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(25,11)})
sns.countplot(x='MaritalStatus',hue='Attrition',data=df,palette='rainbow')

# %%
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(25,11)})
sns.countplot(x='EducationField',hue='Attrition',data=df,palette='rainbow')

# %%
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(25,11)})
sns.countplot(x='JobRole',hue='Attrition',data=df,palette='rainbow')

# %%
sns.set_style('whitegrid')
sns.set(rc={'figure.figsize':(25,11)})
sns.countplot(x='Education',hue='Attrition',data=df,palette='rainbow')

# %%
df.drop(['Over18'], axis = 1,inplace=True)
df.head()
# Out:
#   Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0  51        No  ...                      51                   51
# 1  31       Yes  ...                      31                   31
# 2  32        No  ...                      32                   32
# 3  38        No  ...                      38                   38
# 4  32        No  ...                      32                   32
#
# [5 rows x 23 columns]

# %%
# !pip install category_encoders 
import category_encoders as ce

# %%
df['Attrition'].replace({'Yes':1,'No':0}, inplace=True)
df['Gender'].replace({'Male':1,'Female':0}, inplace=True)
df['MaritalStatus'].replace({'Married':0, 'Single':1, 'Divorced':2}, inplace=True)
df.head()
# Out:
#   Age  Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0  51          0  ...                      51                   51
# 1  31          1  ...                      31                   31
# 2  32          0  ...                      32                   32
# 3  38          0  ...                      38                   38
# 4  32          0  ...                      32                   32
#
# [5 rows x 23 columns]

# %%
a = pd.get_dummies(df.BusinessTravel)
b = pd.get_dummies(df.Department)
c = pd.get_dummies(df.EducationField)
d = pd.get_dummies(df.JobRole)

# %%
df = pd.concat([df,a,b,c,d],axis='columns')
df.head()
# Out:
#   Age  Attrition  ... Sales Executive Sales Representative
# 0  51          0  ...               0                    0
# 1  31          1  ...               0                    0
# 2  32          0  ...               1                    0
# 3  38          0  ...               0                    0
# 4  32          0  ...               1                    0
#
# [5 rows x 44 columns]

# %%
df.drop(['Department'], axis = 1,inplace=True)
df.drop(['BusinessTravel'], axis = 1,inplace=True)
df.drop(['EducationField'], axis = 1,inplace=True)
df.drop(['JobRole'], axis = 1,inplace=True)

# %%
df.head()
# Out:
#   Age  Attrition  ... Sales Executive  Sales Representative
# 0  51          0  ...               0                     0
# 1  31          1  ...               0                     0
# 2  32          0  ...               1                     0
# 3  38          0  ...               0                     0
# 4  32          0  ...               1                     0
#
# [5 rows x 40 columns]

# %%
df.drop(['StandardHours'], axis = 1,inplace=True)
df.drop(['EmployeeCount'], axis = 1,inplace=True)
df.drop(['EmployeeID'], axis = 1,inplace=True)

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(30,20))
sns.heatmap(data=correlation_matrix, annot=True)
